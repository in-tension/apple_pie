# %%
#!/usr/bin/env python
import psutil
import time

# %%
# gives a single float value
psutil.cpu_percent()
# Out:
# 3.1

# %%
# gives an object with many fields
psutil.virtual_memory()
# Out:
# svmem(total=17179869184, available=6990643200, percent=59.3, used=9572876288, free=514301952, active=7689580544, inactive=6441553920, wired=1883295744)

# %%
# you can convert that object to a dictionary 
dict(psutil.virtual_memory()._asdict())
# Out:
# {'total': 17179869184,
#  'available': 6992416768,
#  'percent': 59.3,
#  'used': 9573195776,
#  'free': 516345856,
#  'active': 7689596928,
#  'inactive': 6441283584,
#  'wired': 1883598848}

# %%
times = []

# %%
try:
    while True:
        times.append(psutil.cpu_percent())
        time.sleep(.01)
except KeyboardInterrupt:
    pass

# %%
from matplotlib import pyplot as plt
# %matplotlib notebook
plt.scatter([x for x in range(len(times))],times)
# Out:
# <img src="data:image/png;base64,..." width="664">
